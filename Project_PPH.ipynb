# %% [markdown]
# <a href="https://colab.research.google.com/github/Joksettt/Latihan-PPh/blob/main/Project_PPH.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Task
# tolong buatkan code phyton 3 dan buatkan analisis datanya berupa grafik yang berwarna, serta tolong analisis secara komperhensif dan valid
#
# Here is all the data you need:
# "laporan_akuntansi_pajak_integrasi_2023_2027 (1).csv"

# %% [markdown]
# ## Data loading
#
# ### Subtask:
# Load the data from "laporan_akuntansi_pajak_integrasi_2023_2027 (1).csv" into a pandas DataFrame.

# %% [markdown]
# **Reasoning**:
# Load the data from the provided CSV file into a pandas DataFrame, handling potential encoding issues and displaying the first few rows and the shape of the DataFrame.

# %%
import pandas as pd

try:
    df = pd.read_csv('laporan_akuntansi_pajak_integrasi_2023_2027 (1).csv')
    display(df.head())
    print(df.shape)
except UnicodeDecodeError:
    try:
        df = pd.read_csv('laporan_akuntansi_pajak_integrasi_2023_2027 (1).csv', encoding='latin-1')
        display(df.head())
        print(df.shape)
    except UnicodeDecodeError:
        try:
            df = pd.read_csv('laporan_akuntansi_pajak_integrasi_2023_2027 (1).csv', encoding='iso-8859-1')
            display(df.head())
            print(df.shape)
        except Exception as e:
            print(f"An error occurred: {e}")
            try:
              df = pd.read_csv('laporan_akuntansi_pajak_integrasi_2023_2027 (1).csv', sep=';')
              display(df.head())
              print(df.shape)
            except Exception as e:
              print(f"An error occurred: {e}")
# Out:
#   tahun;persediaan_awal;persediaan_akhir;hpp_rawat_inap;hpp_rawat_jalan;total_hpp;pendapatan_operasional;pendapatan_penjualan;ppn_keluaran;ppn_masukan;ppn_netto;laba_kotor_penjualan;beban_operasional;overhead_farmasi;penyusutan_total;penyusutan_garis_lurus;penyusutan_saldo_menurun;penyusutan_fiskal;laba_kotor_operasional;laba_sebelum_pajak;laba_kena_pajak;tarif_pph_normal;pph_badan_normal;tarif_pph_tax_holiday;pph_badan_tax_holiday;laba_bersih_normal;laba_bersih_tax_holiday;kerugian_fiskal;tax_holiday_status
# 0  2023; 6.395.000 ; 3.151.000 ; 1.830.000 ; 1.41...
# 1  2023; 6.395.000 ; 3.151.000 ; 1.830.000 ; 1.41...
# 2  2023; 6.395.000 ; 3.151.000 ; 1.830.000 ; 1.41...
# 3  2024; 6.714.750 ; 3.308.550 ; 1.921.500 ; 1.48...
# 4  2024; 6.714.750 ; 3.308.550 ; 1.921.500 ; 1.48...
# (37, 1)

# %% [markdown]
# **Reasoning**:
# The previous code block shows that the separator is ';' instead of ','.  Reload the dataframe with the correct separator.

# %%
import pandas as pd
df = pd.read_csv('laporan_akuntansi_pajak_integrasi_2023_2027 (1).csv', sep=';')
display(df.head())
print(df.shape)
# Out:
#   tahun persediaan_awal persediaan_akhir hpp_rawat_inap hpp_rawat_jalan  \
# 0  2023      6.395.000        3.151.000      1.830.000       1.414.000
# 1  2023      6.395.000        3.151.000      1.830.000       1.414.000
# 2  2023      6.395.000        3.151.000      1.830.000       1.414.000
# 3  2024      6.714.750        3.308.550      1.921.500       1.484.700
# 4  2024      6.714.750        3.308.550      1.921.500       1.484.700
#
#      total_hpp pendapatan_operasional pendapatan_penjualan ppn_keluaran  \
# 0   3.244.000              5.200.000            1.957.000      215.270
# 1   3.244.000              4.700.000            1.957.000      215.270
# 2   3.244.000              4.200.000            1.957.000      215.270
# 3   3.406.200              5.700.000            2.054.850      226.034
# 4   3.406.200              5.000.000            2.054.850      226.034
#
#   ppn_masukan  ... laba_sebelum_pajak laba_kena_pajak tarif_pph_normal  \
# ...

# %% [markdown]
# ## Data exploration
#
# ### Subtask:
# Explore the loaded data to understand its structure, identify data types, check for missing values, and examine the statistical distribution of numerical features.

# %% [markdown]
# **Reasoning**:
# I need to explore the data, check data types, missing values, descriptive statistics, and potential key variables.

# %%
# Data Overview
display(df.head())
print(df.shape)

# Data Types
print(df.dtypes)

# Missing Values
print(df.isnull().sum())

# Descriptive Statistics
print(df.describe(include='all'))

# Potential Key Variables (based on initial observation)
potential_key_variables = ['tahun', 'persediaan_awal', 'persediaan_akhir', 'total_hpp', 'pendapatan_operasional', 'pendapatan_penjualan', 'laba_sebelum_pajak', 'laba_kena_pajak', 'pph_badan_normal', 'laba_bersih_normal']
print("\nPotential Key Variables:")
print(potential_key_variables)

# Correlation Analysis (for numerical features)
numerical_features = df.select_dtypes(include=['number'])
correlation_matrix = numerical_features.corr()
display(correlation_matrix)
# Out:
#   tahun persediaan_awal persediaan_akhir hpp_rawat_inap hpp_rawat_jalan  \
# 0  2023      6.395.000        3.151.000      1.830.000       1.414.000
# 1  2023      6.395.000        3.151.000      1.830.000       1.414.000
# 2  2023      6.395.000        3.151.000      1.830.000       1.414.000
# 3  2024      6.714.750        3.308.550      1.921.500       1.484.700
# 4  2024      6.714.750        3.308.550      1.921.500       1.484.700
#
#      total_hpp pendapatan_operasional pendapatan_penjualan ppn_keluaran  \
# 0   3.244.000              5.200.000            1.957.000      215.270
# 1   3.244.000              4.700.000            1.957.000      215.270
# 2   3.244.000              4.200.000            1.957.000      215.270
# 3   3.406.200              5.700.000            2.054.850      226.034
# 4   3.406.200              5.000.000            2.054.850      226.034
#
#   ppn_masukan  ... laba_sebelum_pajak laba_kena_pajak tarif_pph_normal  \
# ...

# %% [markdown]
# **Reasoning**:
# The previous code block has successfully explored the data, but the data needs to be cleaned before further analysis.  Many columns have inconsistent formatting (e.g., numbers as strings with dots and commas). I will address this now.

# %%
import pandas as pd
import numpy as np

# Clean numerical columns (remove dots and commas, convert to numeric)
for col in ['persediaan_awal', 'persediaan_akhir', 'hpp_rawat_inap', 'hpp_rawat_jalan', 'total_hpp', 'pendapatan_operasional',
            'pendapatan_penjualan', 'ppn_keluaran', 'ppn_masukan', 'ppn_netto', 'laba_kotor_penjualan', 'beban_operasional',
            'laba_kotor_operasional', 'laba_sebelum_pajak', 'laba_kena_pajak', 'laba_bersih_normal', 'laba_bersih_tax_holiday']:
    df[col] = df[col].astype(str).str.replace('.', '', regex=False)
    df[col] = df[col].astype(str).str.replace(',', '.', regex=False)
    df[col] = pd.to_numeric(df[col], errors='coerce')

# Display cleaned data
display(df.head())
print(df.dtypes)
print(df.isnull().sum())
# Out:
#   tahun  persediaan_awal  persediaan_akhir  hpp_rawat_inap  hpp_rawat_jalan  \
# 0  2023        6395000.0         3151000.0       1830000.0        1414000.0
# 1  2023        6395000.0         3151000.0       1830000.0        1414000.0
# 2  2023        6395000.0         3151000.0       1830000.0        1414000.0
# 3  2024        6714750.0         3308550.0       1921500.0        1484700.0
# 4  2024        6714750.0         3308550.0       1921500.0        1484700.0
#
#    total_hpp  pendapatan_operasional  pendapatan_penjualan  ppn_keluaran  \
# 0  3244000.0               5200000.0             1957000.0      215270.0
# 1  3244000.0               4700000.0             1957000.0      215270.0
# 2  3244000.0               4200000.0             1957000.0      215270.0
# 3  3406200.0               5700000.0             2054850.0      226034.0
# 4  3406200.0               5000000.0             2054850.0      226034.0
#
# ...

# %% [markdown]
# ## Data cleaning
#
# ### Subtask:
# Data Cleaning: Handle Missing Values and Outliers

# %% [markdown]
# **Reasoning**:
# Impute missing values for numerical and categorical columns, detect and handle outliers, convert data types, and perform consistency checks.

# %%
import pandas as pd
import numpy as np

# Create a copy of the DataFrame to avoid modifying the original
df_cleaned = df.copy()

# 1. Missing Value Imputation
# Numerical Columns
numerical_cols = df_cleaned.select_dtypes(include=np.number).columns
for col in numerical_cols:
    df_cleaned[col] = df_cleaned[col].fillna(df_cleaned[col].median())

# Categorical Columns
categorical_cols = df_cleaned.select_dtypes(exclude=np.number).columns
for col in categorical_cols:
  df_cleaned[col] = df_cleaned[col].fillna(df_cleaned[col].mode()[0])


# 2. Outlier Detection and Handling (using IQR method for demonstration)
for col in numerical_cols:
    Q1 = df_cleaned[col].quantile(0.25)
    Q3 = df_cleaned[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    df_cleaned[col] = np.clip(df_cleaned[col], lower_bound, upper_bound)


# 3. Data Type Conversion (already handled in previous step)

# 4. Consistency Checks (example: check for negative values in revenue)
# Add more consistency checks as needed, based on domain knowledge
for col in ['pendapatan_penjualan', 'pendapatan_operasional', 'laba_bersih_normal']:
    if (df_cleaned[col] < 0).any():
        print(f"Warning: Negative values found in column {col}")
        df_cleaned[col] = df_cleaned[col].abs()


# Display the number of missing values before and after imputation
print("Missing values before imputation:")
print(df.isnull().sum())
print("\nMissing values after imputation:")
print(df_cleaned.isnull().sum())


# Display descriptive statistics before and after cleaning
print("\nDescriptive Statistics Before Cleaning:")
display(df.describe())

print("\nDescriptive Statistics After Cleaning:")
display(df_cleaned.describe())

display(df_cleaned.head())
# Out:
# Missing values before imputation:
# tahun                        6
# persediaan_awal             22
# persediaan_akhir            22
# hpp_rawat_inap              22
# hpp_rawat_jalan             22
# total_hpp                   22
# pendapatan_operasional       7
# pendapatan_penjualan         7
# ppn_keluaran                22
# ppn_masukan                  7
# ppn_netto                   16
# laba_kotor_penjualan         7
# beban_operasional            7
# overhead_farmasi            22
# penyusutan_total            22
# penyusutan_garis_lurus      22
# penyusutan_saldo_menurun    22
# penyusutan_fiskal           22
# laba_kotor_operasional      22
# laba_sebelum_pajak          22
# laba_kena_pajak             22
# tarif_pph_normal            22
# pph_badan_normal            22
# tarif_pph_tax_holiday       22
# pph_badan_tax_holiday       22
# laba_bersih_normal          22
# laba_bersih_tax_holiday     22
# kerugian_fiskal             22
# tax_holiday_status          22
# ...

# %% [markdown]
# ## Data wrangling
#
# ### Subtask:
# Data Wrangling: Feature Engineering and Data Transformation

# %% [markdown]
# **Reasoning**:
# Create new features representing key financial ratios and year-over-year percentage change for key financial metrics.

# %%
import pandas as pd
import numpy as np

# Create a copy to avoid modifying the original DataFrame
df_wrangled = df_cleaned.copy()

# 1. Year-over-year change calculation
for col in ['pendapatan_penjualan', 'total_hpp', 'laba_bersih_normal']:
    df_wrangled[f'YoY_{col}_Change'] = df_wrangled.groupby('tahun')[col].pct_change() * 100
    # Handle the first year (no preceding year)
    df_wrangled[f'YoY_{col}_Change'].fillna(0, inplace=True)

# 2. Ratio calculations
# Avoid division by zero
df_wrangled['Profit_Margin'] = np.where(df_wrangled['pendapatan_penjualan'] != 0,
                                        (df_wrangled['laba_bersih_normal'] / df_wrangled['pendapatan_penjualan']) * 100, 0)
df_wrangled['Operating_Margin'] = np.where(df_wrangled['pendapatan_penjualan'] != 0,
                                          (df_wrangled['pendapatan_operasional'] / df_wrangled['pendapatan_penjualan']) * 100, 0)

# Assuming 'persediaan_awal' and 'persediaan_akhir' represent current assets and liabilities (for demonstration)
df_wrangled['Current_Ratio'] = np.where(df_wrangled['persediaan_akhir'] != 0,
                                        df_wrangled['persediaan_awal'] / df_wrangled['persediaan_akhir'], 0)

# Display the first few rows of the transformed DataFrame
display(df_wrangled.head())
# Out:
# <ipython-input-6-5099f8b1e179>:11: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_wrangled[f'YoY_{col}_Change'].fillna(0, inplace=True)
# <ipython-input-6-5099f8b1e179>:11: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %% [markdown]
# **Reasoning**:
# The previous code block had a chained assignment warning.  I will fix the warning and re-run the code.

# %%
import pandas as pd
import numpy as np

# Create a copy to avoid modifying the original DataFrame
df_wrangled = df_cleaned.copy()

# 1. Year-over-year change calculation
for col in ['pendapatan_penjualan', 'total_hpp', 'laba_bersih_normal']:
    df_wrangled[f'YoY_{col}_Change'] = df_wrangled.groupby('tahun')[col].pct_change() * 100
    # Handle the first year (no preceding year)
    df_wrangled[f'YoY_{col}_Change'] = df_wrangled[f'YoY_{col}_Change'].fillna(0)

# 2. Ratio calculations
# Avoid division by zero
df_wrangled['Profit_Margin'] = np.where(df_wrangled['pendapatan_penjualan'] != 0,
                                        (df_wrangled['laba_bersih_normal'] / df_wrangled['pendapatan_penjualan']) * 100, 0)
df_wrangled['Operating_Margin'] = np.where(df_wrangled['pendapatan_penjualan'] != 0,
                                          (df_wrangled['pendapatan_operasional'] / df_wrangled['pendapatan_penjualan']) * 100, 0)

# Assuming 'persediaan_awal' and 'persediaan_akhir' represent current assets and liabilities (for demonstration)
df_wrangled['Current_Ratio'] = np.where(df_wrangled['persediaan_akhir'] != 0,
                                        df_wrangled['persediaan_awal'] / df_wrangled['persediaan_akhir'], 0)

# Display the first few rows of the transformed DataFrame
display(df_wrangled.head())
# Out:
#   tahun  persediaan_awal  persediaan_akhir  hpp_rawat_inap  hpp_rawat_jalan  \
# 0  2023        7050488.0         3473978.0       2017575.0        1558935.0
# 1  2023        7050488.0         3473978.0       2017575.0        1558935.0
# 2  2023        7050488.0         3473978.0       2017575.0        1558935.0
# 3  2024        7050488.0         3473978.0       2017575.0        1558935.0
# 4  2024        7050488.0         3473978.0       2017575.0        1558935.0
#
#    total_hpp  pendapatan_operasional  pendapatan_penjualan  ppn_keluaran  \
# 0  3576510.0               5200000.0             1957000.0      237335.0
# 1  3576510.0               4700000.0             1957000.0      237335.0
# 2  3576510.0               4200000.0             1957000.0      237335.0
# 3  3576510.0               5700000.0             2054850.0      237335.0
# 4  3576510.0               5000000.0             2054850.0      237335.0
#
#    ppn_masukan  ...  laba_bersih_normal  laba_bersih_tax_holiday  \
# ...

# %% [markdown]
# ## Data analysis
#
# ### Subtask:
# Analyze the wrangled data to identify trends, patterns, and relationships.

# %% [markdown]
# **Reasoning**:
# Calculate descriptive statistics for key financial metrics and perform correlation analysis to understand the relationships between these metrics and YoY changes. Visualize the correlation matrix using a heatmap.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Descriptive Statistics
key_metrics = ['pendapatan_penjualan', 'total_hpp', 'laba_bersih_normal', 'Profit_Margin', 'Operating_Margin', 'Current_Ratio']
descriptive_stats = df_wrangled[key_metrics].describe()
display(descriptive_stats)

# Analyze statistics across different years (if needed)
# Example: Group by year and calculate the mean of key metrics
yearly_stats = df_wrangled.groupby('tahun')[key_metrics].mean()
display(yearly_stats)


# 2. Correlation Analysis and Heatmap
correlation_matrix = df_wrangled[['YoY_pendapatan_penjualan_Change', 'YoY_total_hpp_Change', 'YoY_laba_bersih_normal_Change', 'Profit_Margin', 'Operating_Margin', 'Current_Ratio']].corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='viridis', fmt=".2f")
plt.title('Correlation Matrix of Key Metrics and YoY Changes')
plt.show()

# 3. YoY Change Analysis
# (This will be done in the next step, along with the relationship analysis)

# 4. Relationship between ratios and other variables
# (This will be done in the next step, along with the YoY analysis)
# Out:
#        pendapatan_penjualan  total_hpp  laba_bersih_normal  Profit_Margin  \
# count          3.700000e+01       37.0                37.0   3.700000e+01
# mean           1.061912e+06  3576510.0           1665040.0   1.057532e+07
# std            9.926661e+05        0.0                 0.0   1.576728e+07
# min            4.000000e+00  3576510.0           1665040.0   6.999654e+01
# 25%            8.000000e+00  3576510.0           1665040.0   8.102976e+01
# 50%            9.785150e+05  3576510.0           1665040.0   1.701599e+02
# 75%            2.054850e+06  3576510.0           1665040.0   2.081300e+07
# max            2.378746e+06  3576510.0           1665040.0   4.162600e+07
#
#        Operating_Margin  Current_Ratio
# count      3.700000e+01   3.700000e+01
# mean       5.439354e+06   2.029514e+00
# std        6.996165e+06   4.502149e-16
# min        2.101948e+02   2.029514e+00
# 25%        2.480298e+02   2.029514e+00
# 50%        3.423555e+02   2.029514e+00
# ...

# %% [markdown]
# **Reasoning**:
# Analyze YoY changes to identify periods of significant growth or decline and investigate relationships between calculated ratios and other variables, such as the correlation between profitability and revenue growth.

# %%
import matplotlib.pyplot as plt

# 3. Analyze YoY Changes and identify patterns
plt.figure(figsize=(12, 6))
plt.plot(df_wrangled['tahun'], df_wrangled['YoY_pendapatan_penjualan_Change'], label='Revenue Growth', color='blue')
plt.plot(df_wrangled['tahun'], df_wrangled['YoY_laba_bersih_normal_Change'], label='Net Profit Growth', color='green')
plt.xlabel('Year')
plt.ylabel('YoY Percentage Change')
plt.title('Year-over-Year Growth of Revenue and Net Profit')
plt.legend()
plt.grid(True)
plt.show()


# 4. Investigate Relationships between Ratios and other variables
plt.figure(figsize=(12, 6))
plt.scatter(df_wrangled['YoY_pendapatan_penjualan_Change'], df_wrangled['Profit_Margin'], color='purple')
plt.xlabel('YoY Revenue Growth')
plt.ylabel('Profit Margin')
plt.title('Relationship between Revenue Growth and Profit Margin')
plt.grid(True)
plt.show()

# Analyze potential thresholds (example: find profit margin where revenue growth changes significantly)
# This requires more in-depth analysis, potentially using a statistical method

# Example: Check if high profit margins correlate with high or low revenue growth
print(df_wrangled[['Profit_Margin', 'YoY_pendapatan_penjualan_Change']].corr())
# Out:
#                                  Profit_Margin  \
# Profit_Margin                         1.000000
# YoY_pendapatan_penjualan_Change      -0.191159
#
#                                  YoY_pendapatan_penjualan_Change
# Profit_Margin                                          -0.191159
# YoY_pendapatan_penjualan_Change                         1.000000

# %% [markdown]
# ## Data visualization
#
# ### Subtask:
# Visualize key findings from the data analysis.

# %% [markdown]
# **Reasoning**:
# Generate the required plots to visualize the key findings from the data analysis.

# %%
import matplotlib.pyplot as plt

# 1. Revenue and Profit Trends
plt.figure(figsize=(10, 6))
plt.plot(df_wrangled['tahun'], df_wrangled['pendapatan_penjualan'], label='Revenue', color='blue')
plt.plot(df_wrangled['tahun'], df_wrangled['laba_bersih_normal'], label='Net Profit', color='green')
plt.xlabel('Year')
plt.ylabel('Amount')
plt.title('Revenue and Net Profit Trends')
plt.legend()
plt.grid(True)
plt.show()

# 2. Year-over-Year Growth
plt.figure(figsize=(10, 6))
plt.plot(df_wrangled['tahun'], df_wrangled['YoY_pendapatan_penjualan_Change'], label='Revenue Growth', color='blue')
plt.plot(df_wrangled['tahun'], df_wrangled['YoY_total_hpp_Change'], label='Cost of Goods Sold Growth', color='red')
plt.plot(df_wrangled['tahun'], df_wrangled['YoY_laba_bersih_normal_Change'], label='Net Profit Growth', color='green')
plt.xlabel('Year')
plt.ylabel('YoY Percentage Change')
plt.title('Year-over-Year Growth')
plt.legend()
plt.grid(True)
plt.show()

# 3. Key Ratio Analysis
plt.figure(figsize=(15, 4))

plt.subplot(1, 3, 1)
plt.plot(df_wrangled['tahun'], df_wrangled['Profit_Margin'], label='Profit Margin', color='purple')
plt.xlabel('Year')
plt.ylabel('Percentage')
plt.title('Profit Margin Trend')
plt.grid(True)

plt.subplot(1, 3, 2)
plt.plot(df_wrangled['tahun'], df_wrangled['Operating_Margin'], label='Operating Margin', color='orange')
plt.xlabel('Year')
plt.ylabel('Percentage')
plt.title('Operating Margin Trend')
plt.grid(True)


plt.subplot(1, 3, 3)
plt.plot(df_wrangled['tahun'], df_wrangled['Current_Ratio'], label='Current Ratio', color='brown')
plt.xlabel('Year')
plt.ylabel('Ratio')
plt.title('Current Ratio Trend')
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Summary:
#
# ### Q&A
# No questions to answer.
#
# ### Data Analysis Key Findings
# * The provided CSV file required specifying the separator as ';' during loading.
# * Many numerical columns initially appeared as objects due to formatting (commas and periods as thousands/decimal separators).  Data cleaning converted these to numeric types, introducing NaNs for previously non-numeric values.
# * Missing values were prevalent. Numerical missing values were imputed using the median, and categorical missing values were filled with the mode. Outliers were handled using the IQR method.
# * Year-over-year (YoY) changes were calculated for revenue, cost of goods sold, and net profit.  Financial ratios (profit margin, operating margin, and a current ratio proxy) were computed.
# * Descriptive statistics revealed that `total_hpp` and `laba_bersih_normal` columns appear to have constant values, which may require further investigation.
# * Correlation analysis indicated a weak negative correlation (-0.19) between profit margin and revenue growth.
# * Visualizations showed trends in revenue, net profit, YoY growth rates, profit margin, operating margin, and the current ratio over the years.
#
# ### Insights or Next Steps
# * Investigate the constant values observed in the `total_hpp` and `laba_bersih_normal` columns.  Determine if this is expected behavior or an error in the original data.
# * Explore more sophisticated statistical methods to analyze potential thresholds and relationships between variables, particularly revenue growth and profit margin.  Consider regression analysis or time series modeling to explore these in more depth.

# %% [markdown]
# # Task
# TOLONG BUATKAN CODE PHYTON 3 DAN BUATKAN DATA ANALISIS DATANYA BERUPA GRAFIK BERWARNA, SERTA TOLONG ANALISIS KOMPERHENSIF DAN VALID
#
# Here is all the data you need:
# "laporan_akuntansi_pajak_integrasi_2023_2027 (1).csv"

# %% [markdown]
# ## Data loading
#
# ### Subtask:
# Load the data from "laporan_akuntansi_pajak_integrasi_2023_2027 (1).csv" into a Pandas DataFrame.

# %% [markdown]
# **Reasoning**:
# Load the data from the provided CSV file into a pandas DataFrame, handling potential encoding issues and inspecting the data.

# %%
import pandas as pd

try:
    df = pd.read_csv('laporan_akuntansi_pajak_integrasi_2023_2027 (1).csv', encoding='utf-8', delimiter=';')
except UnicodeDecodeError:
    try:
        df = pd.read_csv('laporan_akuntansi_pajak_integrasi_2023_2027 (1).csv', encoding='latin-1', delimiter=';')
    except UnicodeDecodeError:
        try:
            df = pd.read_csv('laporan_akuntansi_pajak_integrasi_2023_2027 (1).csv', encoding='iso-8859-1', delimiter=';')
        except Exception as e:
            print(f"Error loading the file: {e}")
            df = pd.DataFrame() # Create an empty DataFrame in case of failure

display(df.head())
print(df.dtypes)
# Out:
#   tahun persediaan_awal persediaan_akhir hpp_rawat_inap hpp_rawat_jalan  \
# 0  2023      6.395.000        3.151.000      1.830.000       1.414.000
# 1  2023      6.395.000        3.151.000      1.830.000       1.414.000
# 2  2023      6.395.000        3.151.000      1.830.000       1.414.000
# 3  2024      6.714.750        3.308.550      1.921.500       1.484.700
# 4  2024      6.714.750        3.308.550      1.921.500       1.484.700
#
#      total_hpp pendapatan_operasional pendapatan_penjualan ppn_keluaran  \
# 0   3.244.000              5.200.000            1.957.000      215.270
# 1   3.244.000              4.700.000            1.957.000      215.270
# 2   3.244.000              4.200.000            1.957.000      215.270
# 3   3.406.200              5.700.000            2.054.850      226.034
# 4   3.406.200              5.000.000            2.054.850      226.034
#
#   ppn_masukan  ... laba_sebelum_pajak laba_kena_pajak tarif_pph_normal  \
# ...

# %% [markdown]
# **Reasoning**:
# The data types of several columns need to be corrected.  Specifically, columns that appear to represent numerical values are currently objects, likely due to the presence of thousands separators.  These need to be converted to numeric types after removing the separators.

# %%
import numpy as np

# Columns to clean and convert to numeric
columns_to_convert = ['tahun', 'persediaan_awal', 'persediaan_akhir', 'hpp_rawat_inap', 'hpp_rawat_jalan',
                      'total_hpp', 'pendapatan_operasional', 'pendapatan_penjualan', 'ppn_keluaran',
                      'ppn_masukan', 'ppn_netto', 'laba_kotor_penjualan', 'beban_operasional',
                      'laba_kotor_operasional', 'laba_sebelum_pajak', 'laba_kena_pajak',
                      'laba_bersih_normal','laba_bersih_tax_holiday']

for col in columns_to_convert:
    try:
      df[col] = df[col].astype(str).str.replace('.', '', regex=False)
      df[col] = df[col].str.replace(',', '.', regex=False)
      df[col] = pd.to_numeric(df[col], errors='coerce')
    except Exception as e:
      print(f"Error converting column '{col}': {e}")

display(df.head())
print(df.dtypes)
# Out:
#     tahun  persediaan_awal  persediaan_akhir  hpp_rawat_inap  hpp_rawat_jalan  \
# 0  2023.0        6395000.0         3151000.0       1830000.0        1414000.0
# 1  2023.0        6395000.0         3151000.0       1830000.0        1414000.0
# 2  2023.0        6395000.0         3151000.0       1830000.0        1414000.0
# 3  2024.0        6714750.0         3308550.0       1921500.0        1484700.0
# 4  2024.0        6714750.0         3308550.0       1921500.0        1484700.0
#
#    total_hpp  pendapatan_operasional  pendapatan_penjualan  ppn_keluaran  \
# 0  3244000.0               5200000.0             1957000.0      215270.0
# 1  3244000.0               4700000.0             1957000.0      215270.0
# 2  3244000.0               4200000.0             1957000.0      215270.0
# 3  3406200.0               5700000.0             2054850.0      226034.0
# 4  3406200.0               5000000.0             2054850.0      226034.0
#
# ...

# %% [markdown]
# ## Data exploration
#
# ### Subtask:
# Explore the dataset to understand its structure, identify missing values, data types of each column, and the distribution of key variables.

# %% [markdown]
# **Reasoning**:
# Explore the dataset by examining its shape, data types, descriptive statistics, and distributions of key variables. Visualize the distributions and correlations to identify potential outliers and patterns.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Examine the shape of the DataFrame
print("Shape of the DataFrame:", df.shape)

# 2. Get a concise summary of the DataFrame
print("\nDataFrame Info:")
df.info()

# 3. Calculate descriptive statistics for numerical columns
print("\nDescriptive Statistics:")
display(df.describe())

# 4. Visualize the distribution of key numerical variables
plt.figure(figsize=(20, 15))

plt.subplot(2, 3, 1)
plt.hist(df['pendapatan_operasional'], bins=20, color='skyblue', edgecolor='black')
plt.title('Distribution of Pendapatan Operasional')

plt.subplot(2, 3, 2)
plt.hist(df['laba_bersih_normal'], bins=20, color='lightgreen', edgecolor='black')
plt.title('Distribution of Laba Bersih Normal')

plt.subplot(2, 3, 3)
plt.hist(df['total_hpp'], bins=20, color='lightcoral', edgecolor='black')
plt.title('Distribution of Total HPP')

plt.subplot(2, 3, 4)
plt.hist(df['tahun'], bins=20, color='lightblue', edgecolor='black')
plt.title('Distribution of Tahun')

plt.subplot(2, 3, 5)
sns.boxplot(x=df['pendapatan_operasional'], color='skyblue')
plt.title('Boxplot of Pendapatan Operasional')

plt.subplot(2, 3, 6)
sns.boxplot(x=df['laba_bersih_normal'], color='lightgreen')
plt.title('Boxplot of Laba Bersih Normal')


plt.tight_layout()
plt.show()

# 5. Investigate the correlation between relevant numerical variables
print("\nCorrelation Matrix:")
correlation_matrix = df.corr()
display(correlation_matrix)

plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix Heatmap')
plt.show()

# 6. Check for unique values in categorical columns
categorical_columns = df.select_dtypes(include=['object']).columns
for col in categorical_columns:
    print(f'\nUnique values and frequencies for {col}:')
    print(df[col].value_counts())

# 7. Initial observations and documentation
print("\nInitial Observations:")
# Add your observations about missing values, outliers, and patterns here
# Example: "Missing values: There are missing values in column X, which might ..."
# Out:
# Shape of the DataFrame: (37, 29)
#
# DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 29 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   tahun                     15 non-null     float64
#  1   persediaan_awal           15 non-null     float64
#  2   persediaan_akhir          15 non-null     float64
#  3   hpp_rawat_inap            15 non-null     float64
#  4   hpp_rawat_jalan           15 non-null     float64
#  5   total_hpp                 15 non-null     float64
#  6   pendapatan_operasional    30 non-null     float64
#  7   pendapatan_penjualan      30 non-null     float64
#  8   ppn_keluaran              15 non-null     float64
#  9   ppn_masukan               30 non-null     float64
#  10  ppn_netto                 21 non-null     float64
#  11  laba_kotor_penjualan      30 non-null     float64
# ...

# %% [markdown]
# **Reasoning**:
# The previous code failed due to a `ValueError` when converting the 'tarif_pph_normal' column to numeric because it contains percentage signs. I will modify the code to handle this error gracefully.  The code should also be updated to handle other potential non-numeric values in other columns.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Examine the shape of the DataFrame
print("Shape of the DataFrame:", df.shape)

# 2. Get a concise summary of the DataFrame
print("\nDataFrame Info:")
df.info()

# 3. Calculate descriptive statistics for numerical columns
print("\nDescriptive Statistics:")
display(df.describe(include='all'))

# 4. Visualize the distribution of key numerical variables
plt.figure(figsize=(20, 15))

plt.subplot(2, 3, 1)
plt.hist(df['pendapatan_operasional'].dropna(), bins=20, color='skyblue', edgecolor='black')
plt.title('Distribution of Pendapatan Operasional')

plt.subplot(2, 3, 2)
plt.hist(df['laba_bersih_normal'].dropna(), bins=20, color='lightgreen', edgecolor='black')
plt.title('Distribution of Laba Bersih Normal')

plt.subplot(2, 3, 3)
plt.hist(df['total_hpp'].dropna(), bins=20, color='lightcoral', edgecolor='black')
plt.title('Distribution of Total HPP')

plt.subplot(2, 3, 4)
plt.hist(df['tahun'].dropna(), bins=20, color='lightblue', edgecolor='black')
plt.title('Distribution of Tahun')

plt.subplot(2, 3, 5)
sns.boxplot(x=df['pendapatan_operasional'].dropna(), color='skyblue')
plt.title('Boxplot of Pendapatan Operasional')

plt.subplot(2, 3, 6)
sns.boxplot(x=df['laba_bersih_normal'].dropna(), color='lightgreen')
plt.title('Boxplot of Laba Bersih Normal')


plt.tight_layout()
plt.show()


# 5. Investigate the correlation between relevant numerical variables
# Exclude non-numeric columns for correlation calculation
numeric_df = df.select_dtypes(include=['number'])
print("\nCorrelation Matrix:")
correlation_matrix = numeric_df.corr()
display(correlation_matrix)

plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix Heatmap')
plt.show()

# 6. Check for unique values in categorical columns
categorical_columns = df.select_dtypes(include=['object']).columns
for col in categorical_columns:
    print(f'\nUnique values and frequencies for {col}:')
    print(df[col].value_counts())

# 7. Initial observations and documentation
print("\nInitial Observations:")
# Add your observations about missing values, outliers, and patterns here
# Out:
# Shape of the DataFrame: (37, 29)
#
# DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 29 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   tahun                     15 non-null     float64
#  1   persediaan_awal           15 non-null     float64
#  2   persediaan_akhir          15 non-null     float64
#  3   hpp_rawat_inap            15 non-null     float64
#  4   hpp_rawat_jalan           15 non-null     float64
#  5   total_hpp                 15 non-null     float64
#  6   pendapatan_operasional    30 non-null     float64
#  7   pendapatan_penjualan      30 non-null     float64
#  8   ppn_keluaran              15 non-null     float64
#  9   ppn_masukan               30 non-null     float64
#  10  ppn_netto                 21 non-null     float64
#  11  laba_kotor_penjualan      30 non-null     float64
# ...

# %% [markdown]
# ## Data cleaning
#
# ### Subtask:
# Clean the data by handling missing values and inconsistencies.

# %% [markdown]
# **Reasoning**:
# Clean the data by handling missing values, inconsistencies in the `tarif_pph_normal` column, removing duplicates, and converting data types as instructed.

# %%
# 1. Handle Missing Values
for col in df.select_dtypes(include=['number']):
    df[col].fillna(df[col].median(), inplace=True)

for col in df.select_dtypes(include=['object']):
    df[col].fillna(df[col].mode()[0], inplace=True)

# 2. Address Inconsistencies in 'tarif_pph_normal'
df['tarif_pph_normal'] = df['tarif_pph_normal'].astype(str).str.replace('%', '', regex=False)
df['tarif_pph_normal'] = pd.to_numeric(df['tarif_pph_normal'], errors='coerce')

# 3. Remove Duplicates
num_duplicates = df.duplicated().sum()
df.drop_duplicates(inplace=True)
print(f"Removed {num_duplicates} duplicate rows.")

# 4. Data Type Conversion (Already handled in previous steps for relevant columns)

# Display the cleaned DataFrame
display(df.head())
print(df.info())
# Out:
# Removed 16 duplicate rows.
# <ipython-input-5-db555c35bb6d>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# <ipython-input-5-db555c35bb6d>:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %% [markdown]
# **Reasoning**:
# The previous code block had warnings about chained assignment.  I will rewrite the code to correct these warnings and ensure the operations are performed in place on the original DataFrame.

# %%
# 1. Handle Missing Values
for col in df.select_dtypes(include=['number']):
    df[col] = df[col].fillna(df[col].median())

for col in df.select_dtypes(include=['object']):
    df[col] = df[col].fillna(df[col].mode()[0])

# 2. Address Inconsistencies in 'tarif_pph_normal'
df['tarif_pph_normal'] = df['tarif_pph_normal'].astype(str).str.replace('%', '', regex=False)
df['tarif_pph_normal'] = pd.to_numeric(df['tarif_pph_normal'], errors='coerce')

# 3. Remove Duplicates
num_duplicates = df.duplicated().sum()
df = df.drop_duplicates()
print(f"Removed {num_duplicates} duplicate rows.")

# 4. Data Type Conversion (Already handled in previous steps for relevant columns)

# Display the cleaned DataFrame
display(df.head())
print(df.info())
# Out:
# Removed 0 duplicate rows.
#     tahun  persediaan_awal  persediaan_akhir  hpp_rawat_inap  hpp_rawat_jalan  \
# 0  2023.0        6395000.0         3151000.0       1830000.0        1414000.0
# 1  2023.0        6395000.0         3151000.0       1830000.0        1414000.0
# 2  2023.0        6395000.0         3151000.0       1830000.0        1414000.0
# 3  2024.0        6714750.0         3308550.0       1921500.0        1484700.0
# 4  2024.0        6714750.0         3308550.0       1921500.0        1484700.0
#
#    total_hpp  pendapatan_operasional  pendapatan_penjualan  ppn_keluaran  \
# 0  3244000.0               5200000.0             1957000.0      215270.0
# 1  3244000.0               4700000.0             1957000.0      215270.0
# 2  3244000.0               4200000.0             1957000.0      215270.0
# 3  3406200.0               5700000.0             2054850.0      226034.0
# 4  3406200.0               5000000.0             2054850.0      226034.0
#
# ...

# %% [markdown]
# ## Data wrangling
#
# ### Subtask:
# Data Wrangling and Feature Engineering

# %% [markdown]
# **Reasoning**:
# Calculate year-over-year changes, financial ratios, and tax holiday impact, handling potential division by zero errors.

# %%
# Calculate year-over-year percentage change for key metrics
for metric in ['pendapatan_operasional', 'laba_bersih_normal', 'total_hpp']:
    df[f'YoY_{metric}'] = df[metric].pct_change() * 100
    # Handle the first year (no YoY change)
    df[f'YoY_{metric}'].fillna(0, inplace=True)

# Calculate financial ratios, handling potential division by zero
epsilon = 1e-9  # Small value to avoid division by zero
df['Gross_Profit_Margin'] = (df['laba_kotor_penjualan'] / (df['pendapatan_penjualan'] + epsilon)) * 100
df['Operating_Profit_Margin'] = (df['laba_kotor_operasional'] / (df['pendapatan_operasional'] + epsilon)) * 100
df['Net_Profit_Margin'] = (df['laba_bersih_normal'] / (df['pendapatan_operasional'] + epsilon)) * 100
df['Tax_Holiday_Impact_Ratio'] = (df['laba_bersih_tax_holiday'] / (df['pendapatan_operasional'] + epsilon)) * 100


# Calculate the difference between laba_bersih_normal and laba_bersih_tax_holiday
df['Tax_Holiday_Impact'] = df['laba_bersih_normal'] - df['laba_bersih_tax_holiday']

display(df.head())
# Out:
# <ipython-input-7-c2433c28b4e1>:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[f'YoY_{metric}'].fillna(0, inplace=True)
# <ipython-input-7-c2433c28b4e1>:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %% [markdown]
# **Reasoning**:
# Fix the chained assignment warnings and complete the data wrangling and feature engineering subtask.

# %%
# Calculate year-over-year percentage change for key metrics
for metric in ['pendapatan_operasional', 'laba_bersih_normal', 'total_hpp']:
    df[f'YoY_{metric}'] = df.groupby('tahun')[metric].pct_change() * 100
    # Handle the first year (no YoY change)
    df[f'YoY_{metric}'].fillna(0, inplace=True)

# Calculate financial ratios, handling potential division by zero
epsilon = 1e-9  # Small value to avoid division by zero
df['Gross_Profit_Margin'] = (df['laba_kotor_penjualan'] / (df['pendapatan_penjualan'] + epsilon)) * 100
df['Operating_Profit_Margin'] = (df['laba_kotor_operasional'] / (df['pendapatan_operasional'] + epsilon)) * 100
df['Net_Profit_Margin'] = (df['laba_bersih_normal'] / (df['pendapatan_operasional'] + epsilon)) * 100
df['Tax_Holiday_Impact_Ratio'] = (df['laba_bersih_tax_holiday'] / (df['pendapatan_operasional'] + epsilon)) * 100


# Calculate the difference between laba_bersih_normal and laba_bersih_tax_holiday
df['Tax_Holiday_Impact'] = df['laba_bersih_normal'] - df['laba_bersih_tax_holiday']

display(df.head())
# Out:
# <ipython-input-8-8342daf4967a>:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[f'YoY_{metric}'].fillna(0, inplace=True)
#     tahun  persediaan_awal  persediaan_akhir  hpp_rawat_inap  hpp_rawat_jalan  \
# 0  2023.0        6395000.0         3151000.0       1830000.0        1414000.0
# 1  2023.0        6395000.0         3151000.0       1830000.0        1414000.0
# 2  2023.0        6395000.0         3151000.0       1830000.0        1414000.0
# ...

# %% [markdown]
# **Reasoning**:
# The previous attempts to fix the inplace operation warning were not successful.  I will try one more time to fix the warning and then finish the task.

# %%
# Calculate year-over-year percentage change for key metrics
for metric in ['pendapatan_operasional', 'laba_bersih_normal', 'total_hpp']:
    df[f'YoY_{metric}'] = df.groupby('tahun')[metric].pct_change() * 100
    # Handle the first year (no YoY change)
    df[f'YoY_{metric}'] = df[f'YoY_{metric}'].fillna(0)

# Calculate financial ratios, handling potential division by zero
epsilon = 1e-9  # Small value to avoid division by zero
df['Gross_Profit_Margin'] = (df['laba_kotor_penjualan'] / (df['pendapatan_penjualan'] + epsilon)) * 100
df['Operating_Profit_Margin'] = (df['laba_kotor_operasional'] / (df['pendapatan_operasional'] + epsilon)) * 100
df['Net_Profit_Margin'] = (df['laba_bersih_normal'] / (df['pendapatan_operasional'] + epsilon)) * 100
df['Tax_Holiday_Impact_Ratio'] = (df['laba_bersih_tax_holiday'] / (df['pendapatan_operasional'] + epsilon)) * 100


# Calculate the difference between laba_bersih_normal and laba_bersih_tax_holiday
df['Tax_Holiday_Impact'] = df['laba_bersih_normal'] - df['laba_bersih_tax_holiday']

display(df.head())
# Out:
#     tahun  persediaan_awal  persediaan_akhir  hpp_rawat_inap  hpp_rawat_jalan  \
# 0  2023.0        6395000.0         3151000.0       1830000.0        1414000.0
# 1  2023.0        6395000.0         3151000.0       1830000.0        1414000.0
# 2  2023.0        6395000.0         3151000.0       1830000.0        1414000.0
# 3  2024.0        6714750.0         3308550.0       1921500.0        1484700.0
# 4  2024.0        6714750.0         3308550.0       1921500.0        1484700.0
#
#    total_hpp  pendapatan_operasional  pendapatan_penjualan  ppn_keluaran  \
# 0  3244000.0               5200000.0             1957000.0      215270.0
# 1  3244000.0               4700000.0             1957000.0      215270.0
# 2  3244000.0               4200000.0             1957000.0      215270.0
# 3  3406200.0               5700000.0             2054850.0      226034.0
# 4  3406200.0               5000000.0             2054850.0      226034.0
#
# ...

# %% [markdown]
# ## Data visualization
#
# ### Subtask:
# Visualize key financial metrics and ratios over time.

# %% [markdown]
# **Reasoning**:
# Visualize the key financial metrics, ratios, and tax holiday impact using line plots and a bar chart as specified in the instructions.

# %%
import matplotlib.pyplot as plt

# Financial Metrics over Time
plt.figure(figsize=(16, 6))
plt.plot(df['tahun'], df['pendapatan_operasional'], label='Pendapatan Operasional', color='skyblue')
plt.plot(df['tahun'], df['laba_bersih_normal'], label='Laba Bersih Normal', color='lightgreen')
plt.plot(df['tahun'], df['total_hpp'], label='Total HPP', color='lightcoral')
plt.xlabel('Tahun')
plt.ylabel('Nilai (IDR)')
plt.title('Tren Metrik Keuangan Utama')
plt.legend()
plt.grid(True)
plt.show()


# YoY Percentage Change
plt.figure(figsize=(16, 6))
plt.plot(df['tahun'], df['YoY_pendapatan_operasional'], label='YoY Pendapatan Operasional', color='skyblue')
plt.plot(df['tahun'], df['YoY_laba_bersih_normal'], label='YoY Laba Bersih Normal', color='lightgreen')
plt.plot(df['tahun'], df['YoY_total_hpp'], label='YoY Total HPP', color='lightcoral')
plt.xlabel('Tahun')
plt.ylabel('Persentase (%)')
plt.title('Perubahan Persentase Tahun ke Tahun')
plt.legend()
plt.grid(True)
plt.show()


# Financial Ratios over Time
plt.figure(figsize=(16, 6))
plt.plot(df['tahun'], df['Gross_Profit_Margin'], label='Gross Profit Margin', color='blue')
plt.plot(df['tahun'], df['Operating_Profit_Margin'], label='Operating Profit Margin', color='green')
plt.plot(df['tahun'], df['Net_Profit_Margin'], label='Net Profit Margin', color='red')
plt.plot(df['tahun'], df['Tax_Holiday_Impact_Ratio'], label='Tax Holiday Impact Ratio', color='purple')
plt.xlabel('Tahun')
plt.ylabel('Rasio (%)')
plt.title('Rasio Keuangan')
plt.legend()
plt.grid(True)
plt.show()


# Tax Holiday Impact over Time
plt.figure(figsize=(16, 6))
plt.bar(df['tahun'], df['Tax_Holiday_Impact'], color='skyblue')
plt.xlabel('Tahun')
plt.ylabel('Impact (IDR)')
plt.title('Dampak Tax Holiday')
plt.grid(axis='y')
plt.show()

# %% [markdown]
# ## Summary:
#
# ### Q&A
# No questions were posed in the task.
#
# ### Data Analysis Key Findings
# * **Data Cleaning:** Missing numerical values were imputed using the median, while missing categorical values were filled with the mode. The `tarif_pph_normal` column was cleaned by removing percentage symbols and converting it to numeric. Duplicate rows were removed.
# * **Feature Engineering:** Year-over-year (YoY) percentage changes were calculated for key financial metrics (revenue, net profit, total cost of goods sold). Several financial ratios were computed, including gross profit margin, operating profit margin, net profit margin, and a tax holiday impact ratio.  A new feature, `Tax_Holiday_Impact`, representing the difference between normal and tax-holiday net profits, was created.
# * **Financial Trends:** Visualizations revealed trends in key financial metrics and ratios over time.  YoY changes and financial ratios provided insights into the company's performance and the impact of tax holidays.  The visualizations included line plots for financial metrics, YoY changes, and financial ratios, as well as a bar chart for the tax holiday impact.
#
#
# ### Insights or Next Steps
# * **Analyze the impact of tax holidays:** Further investigate the relationship between tax holidays and financial performance, potentially using regression analysis.
# * **Deep dive into financial ratios:** Explore the trends and fluctuations in financial ratios to identify potential areas of strength or weakness in the company's financial health.
